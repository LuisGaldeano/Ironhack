# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import pandas as pd
import numpy as np
import pylab as plt
import seaborn as sns
import matplotlib.pyplot as plt
# Your Code Here

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('../data/Fitbit2.csv')

# %%
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary
# 0  2015-05-08            1934    905      0.65       0              1.355  \
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active
# 0                      46                      0                    0  \
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED
# your code here
monsteps = fitbit.groupby(['Months_encoded', 'Work_or_Weekend'])['Steps'].median().reset_index()

# %%
fig, ax = plt.subplots(figsize=(12, 4))
plt.xticks(rotation=35) 
sns.barplot(data=monsteps,
            x='Months_encoded',
            y='Steps',
            hue='Work_or_Weekend',
            palette='Blues');

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
# your code here
wow = fitbit.groupby('Work_or_Weekend')['Steps'].median().reset_index()

fig, ax = plt.subplots(figsize=(12, 4))

sns.barplot(data=wow,
            x='Work_or_Weekend',
            y='Steps',
            palette='Blues');

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
col = ['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary']
fig, ax = plt.subplots(1, 3, 
                       figsize=(12, 6))

for i in range(3):
    sns.scatterplot(ax= ax[i] , 
                    data=fitbit,
                    x=col[i], 
                    y='Steps')

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('../data/titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1       0.0       3  \
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(include=('float64', 'int64')).head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(include='object').head()
# Out:
#                                                 Name  Gender
# 0                            Braund, Mr. Owen Harris    male  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use('classic')
plt.figure(figsize=(12, 6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
sns.displot(x=titanic.Age);

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

f1 = sns.histplot(x=titanic.Age, bins=10, kde=True, ax=axes[0]);
f2 = sns.histplot(x=titanic.Age, bins=20, kde=True, ax=axes[1]);
f3 = sns.histplot(x=titanic.Age, bins=50, kde=True, ax=axes[2]);

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
Visualmente no afecta, lo único que se ve con más detalle o con menos ya que está más o menos agrupado
"""
# Out:
# '\nVisualmente no afecta, lo único que se ve con más detalle o con menos ya que está más o menos agrupado\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.histplot(data=titanic, x="Age", kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
gen = titanic['Gender'].value_counts()

fig, ax = plt.subplots(1, 1, figsize=(12, 4))
ax.set_xlabel('Count')
ax.set_ylabel('Gender')
ax.bar(gen.index, gen.values)
# Out:
# <BarContainer object of 2 artists>

# %%
# Method 2 - seaborn
# your code here
sns.countplot(x=titanic.Gender);

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
titanic.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1       0.0       3  \
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %%
pc = titanic['Pclass'].value_counts()

plt.figure(figsize=(8, 6))
sns.barplot(x=labels, y=sizes, palette=colors)

plt.xlabel('Clase')
plt.ylabel('Cantidad')
plt.title('Distribución de la clase')
# Out:
# Text(0.5, 1.0, 'Distribución de la clase')

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
fig, axes = plt.subplots(figsize=(12, 4))
sns.boxplot(data=titanic.Age, color='blue');

# %%
"""
Este gráfico es el que más información me da porque me muestra los valores standard y los outliers
"""
# Out:
# '\nEste gráfico es el que más información me da porque me muestra los valores standard y los outliers\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
Que la mayoría de gente estaba entre los 20 y los 40 años
"""
# Out:
# '\nQue la mayoría de gente estaba entre los 20 y los 40 años\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
